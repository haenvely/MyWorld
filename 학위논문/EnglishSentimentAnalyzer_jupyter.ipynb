# %%
import pandas as pd
import pyTextMiner as ptm
import io
from nltk.corpus import sentiwordnet as swn
import nltk

class EnglishDictionarySentimentAnalyzer:
    def __init__(self):
        name = 'EnglishDictionarySentimentAnalyzer'

    def createDictionary(self):
        nltk.download('sentiwordnet')

# %%
    #이문장은 임의추가
tweet_raw = pd.read_csv('C:/Users/ohi02/PycharmProjects/HelloWorld/SuperbowlData/preprocess_2019hyundai.csv')
corpus = list(tweet_raw.text)

#print(corpus)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fbb83981a815> in <module>
#       1 #이문장은 임의추가
# ----> 2 tweet_raw = pd.read_csv('C:/Users/ohi02/PycharmProjects/HelloWorld/SuperbowlData/preprocess_2019hyundai.csv')
#       3 corpus = list(tweet_raw.text)
#       4
#       5 #print(corpus)
#
# NameError: name 'pd' is not defined

# %%
pipeline = ptm.Pipeline()
result = pipeline.processCorpus(corpus)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-8341df4cf442> in <module>
#       1 pipeline = ptm.Pipeline()
# ----> 2 result = pipeline.processCorpus(corpus)
#
# ~\PycharmProjects\pyTextMiner1.1\pyTextMiner\__init__.py in processCorpus(self, corpus)
#      52         for d in corpus:
#      53             inst = d
# ---> 54             for p, c in zip(self.pipeline, self.collapse):
#      55                 inst = apply(p, c, inst)
#      56             results.append(inst)
#
# TypeError: zip argument #2 must support iteration

# %%
corpus = []
for i in range(len(tweet_raw)):
    corpus[i] = tweet_raw['text'][i]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-fc3b69572d10> in <module>
#       1 corpus = []
#       2 for i in range(len(tweet_raw)):
# ----> 3     corpus[i] = tweet_raw['text'][i]
#
# IndexError: list assignment index out of range

# %%
print(corpus)
# Out:
# ['Yeah they make them in very cheesy way be squirm while see it and now want be take on date in Hyundai car with man the pull the moon closer for me', 'The price have change on our 2017 Hyundai Santa Fe Take look : http : //www.carsforsale.com/vehicle/details/3-25780950', 'The price for 2015 Hyundai Genesis $ 2,299 now Take look : http : //www.carsforsale.com/vehicle/details/3-26627002', 'The price for 2017 Hyundai Santa Fe $ 2,499 now Take look : http : //www.carsforsale.com/vehicle/details/3-25780910', 'The price for 2007 Hyundai Elantra $ 4,582 now Take look : http : //www.carsforsale.com/vehicle/details/3-14840194', 'The price have change on our 2015 Hyundai Sonata Hybrid Take look : http : //www.carsforsale.com/vehicle/details/3-25089180', 'The price for 2006 Hyundai Sonata $ 4,682 now Take look : http : //www.carsforsale.com/vehicle/details/3-7423589', 'Just in ! We have recently add 2012 Hyundai Sonata our inventory Check it out : http : //tinyurl.com/y759rft5', 'COVERCRAFT SS
# ...
