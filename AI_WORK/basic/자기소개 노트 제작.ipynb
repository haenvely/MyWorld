# %% [markdown]
# # 자기 소개
# ## 관심사
# ### 국내여행
#
#
# ![속초](./속초하늘.jpg)
#
#
# ### 해외여행
# ![샌프란시스코](./샌프란.jpg)
#
# _____
# _____
#
#
# ## 취미
# 1. 여행하기
# 1. 핫플 탐방
# 1. 맛집 투어
# 1. SNS 관리
#   * [블로그](https://blog.naver.com/haen0202 "블로그로 이동")
#   + [인스타그램](https://www.instagram.com/haen.log "인스타그램으로 이동")
#
# _____
# _____
#
#
#
# ## 관심 skill
# - 추천시스템
#   - 카드 데이터 활용한 맞춤 상품 추천
#   - 지식그래프 활용한 추천 알고리즘
#
# _____
# _____
#
#
# ## 자주 사용하는 library
# ```python
# import pandas
# import numpy
# import matplotlib
# import konlpy
# ```
#
# `kkma`
# `okt`
# `komoran`
# _____
# _____
#
#
# ## 넷플릭스 추천
#
# | 제목 | 영화/드라마/예능 | 시리즈 |
# |---|:---:|---:|
# |프렌즈|<u>미국</u> 시트콤 드라마|O|
# |SKY캐슬|<u>한국</u> 드라마|X|
# |청설|<u>대만</u> 영화|X|
#
# ## 읽고 있는 책
#
# > 비와 별이 내리는 밤 - 메이브 빈치
