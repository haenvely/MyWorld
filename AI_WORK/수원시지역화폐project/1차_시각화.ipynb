# %%
import numpy as np
import pandas as pd

# %%
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
data=pd.read_csv('수원시_지역화폐 결제 정보_20201211.csv', encoding='CP949')

# %%
data.head(5)
# Out:
#          기준년월 시군구명 읍면동명 성별  연령대    업종명  결제건수     결제금액     데이터기준일자
# 0  2020-11-01  권선구  고색동  남  10대   레져업소    20   106900  2020-12-11
# 1  2020-11-01  권선구  고색동  남  10대   보건위생     3    29000  2020-12-11
# 2  2020-11-01  권선구  고색동  남  10대   서적문구     1     5600  2020-12-11
# 3  2020-11-01  권선구  고색동  남  10대     약국     1    13600  2020-12-11
# 4  2020-11-01  권선구  고색동  남  10대  유통업영리    70  2160910  2020-12-11

# %%
data.isnull().sum()
# Out:
# 기준년월       0
# 시군구명       0
# 읍면동명       0
# 성별         0
# 연령대        0
# 업종명        0
# 결제건수       0
# 결제금액       0
# 데이터기준일자    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128650 entries, 0 to 128649
# Data columns (total 9 columns):
# 기준년월       128650 non-null object
# 시군구명       128650 non-null object
# 읍면동명       128650 non-null object
# 성별         128650 non-null object
# 연령대        128650 non-null object
# 업종명        128650 non-null object
# 결제건수       128650 non-null int64
# 결제금액       128650 non-null int64
# 데이터기준일자    128650 non-null object
# dtypes: int64(2), object(7)
# memory usage: 8.8+ MB

# %%
data.describe(include='all')
# Out:
#               기준년월    시군구명    읍면동명      성별     연령대      업종명           결제건수  \
# count       128650  128650  128650  128650  128650   128650  128650.000000
# unique          20       4      56       2       7       34            NaN
# top     2020-05-01     팔달구     영통동       여     20대  일반·휴게음식            NaN
# freq         10752   41216    4458   64568   28124    11951            NaN
# mean           NaN     NaN     NaN     NaN     NaN      NaN      91.834046
# std            NaN     NaN     NaN     NaN     NaN      NaN     373.815329
# min            NaN     NaN     NaN     NaN     NaN      NaN       1.000000
# 25%            NaN     NaN     NaN     NaN     NaN      NaN       2.000000
# 50%            NaN     NaN     NaN     NaN     NaN      NaN       7.000000
# 75%            NaN     NaN     NaN     NaN     NaN      NaN      32.000000
# max            NaN     NaN     NaN     NaN     NaN      NaN   12670.000000
#
#                 결제금액     데이터기준일자
# count   1.286500e+05      128650
# ...

# %%
a=data['기준년월'].str.split('-')

# %%
data['기준년월']=a.str.join('')

# %%
data.head(5)
# Out:
#        기준년월 시군구명 읍면동명 성별  연령대    업종명  결제건수     결제금액     데이터기준일자
# 0  20201101  권선구  고색동  남  10대   레져업소    20   106900  2020-12-11
# 1  20201101  권선구  고색동  남  10대   보건위생     3    29000  2020-12-11
# 2  20201101  권선구  고색동  남  10대   서적문구     1     5600  2020-12-11
# 3  20201101  권선구  고색동  남  10대     약국     1    13600  2020-12-11
# 4  20201101  권선구  고색동  남  10대  유통업영리    70  2160910  2020-12-11

# %%
data.기준년월.value_counts()
# Out:
# 20200501    10752
# 20200601    10267
# 20201001     9641
# 20200701     9500
# 20201101     9288
# 20200901     9247
# 20200801     8791
# 20200401     8529
# 20200301     5676
# 20200101     4947
# 20191201     4933
# 20200201     4789
# 20191001     4754
# 20191101     4650
# 20190801     4523
# 20190901     4408
# 20190601     4237
# 20190701     4198
# 20190501     3994
# 20190401     1526
# Name: 기준년월, dtype: int64

# %%
data.연령대.value_counts()
# Out:
# 20대      28124
# 40대      26176
# 30대      25509
# 50대      23453
# 60대이상    16436
# 10대       8638
# 10세미만      314
# Name: 연령대, dtype: int64

# %%
data.기준년월=data.기준년월.astype('int')

# %%
data
# Out:
#             기준년월 시군구명 읍면동명 성별    연령대       업종명  결제건수      결제금액     데이터기준일자
# 0       20201101  권선구  고색동  남    10대      레져업소    20    106900  2020-12-11
# 1       20201101  권선구  고색동  남    10대      보건위생     3     29000  2020-12-11
# 2       20201101  권선구  고색동  남    10대      서적문구     1      5600  2020-12-11
# 3       20201101  권선구  고색동  남    10대        약국     1     13600  2020-12-11
# 4       20201101  권선구  고색동  남    10대     유통업영리    70   2160910  2020-12-11
# 5       20201101  권선구  고색동  남    10대      음료식품    10    102700  2020-12-11
# 6       20201101  권선구  고색동  남    10대        의원     2    207200  2020-12-11
# 7       20201101  권선구  고색동  남    10대   일반·휴게음식    39    547300  2020-12-11
# 8       20201101  권선구  고색동  남    10대        학원     2    660000  2020-12-11
# 9       20201101  권선구  고색동  남    20대        기타     1    154000  2020-12-11
# 10      20201101  권선구  고색동  남    20대      레져업소    34    287200  2020-12-11
# ...

# %%
data_20=data.loc[(data.기준년월 >= 20200101) & (data.기준년월 <=20201231)]
data_19=data.loc[(data.기준년월 >= 20190101) & (data.기준년월 <=20191231)]

# %%
((len(data_20) + len(data_19)) == len(data))
# Out:
# True

# %%
data_20_1=data.loc[(data.기준년월 >= 20200101) & (data.기준년월 <=20200331)]
data_20_2=data.loc[(data.기준년월 >= 20200401) & (data.기준년월 <=20200631)]
data_20_3=data.loc[(data.기준년월 >= 20200701) & (data.기준년월 <=20200931)]
data_20_4=data.loc[(data.기준년월 >= 20201001) & (data.기준년월 <=20201231)]

data_19_1=data.loc[(data.기준년월 >= 20190101) & (data.기준년월 <=20190331)]
data_19_2=data.loc[(data.기준년월 >= 20190401) & (data.기준년월 <=20190631)]
data_19_3=data.loc[(data.기준년월 >= 20190701) & (data.기준년월 <=20190931)]
data_19_4=data.loc[(data.기준년월 >= 20191001) & (data.기준년월 <=20191231)]

# %%
a = len(data_20_1) + len(data_20_2) + len(data_20_3) + len(data_20_4)

b = len(data_19_1) + len(data_19_2) + len(data_19_3) + len(data_19_4)

((a+b) == len(data))
# Out:
# True

# %%
(len(data_20) == a)

(len(data_19) == b)
# Out:
# True

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns 
sns.set()

# %%
_20_1=round(data_20_1['결제금액'].mean(),2)
_20_2=round(data_20_2['결제금액'].mean(),2)
_20_3=round(data_20_3['결제금액'].mean(),2)
_20_4=round(data_20_4['결제금액'].mean(),2)

# 19년도 1분기 데이터 존재하지 않음
# _19_1=round(data_19_1['결제금액'].mean(),2)
_19_2=round(data_19_2['결제금액'].mean(),2)
_19_3=round(data_19_3['결제금액'].mean(),2)
_19_4=round(data_19_4['결제금액'].mean(),2)

# %%
_20_1
_20_2
_20_3
_20_4
_19_2
_19_3
_19_4
# Out:
# 717617.08

# %%
def round_2(x):
    return round(x,2)

#년도별 분기당 남녀평균소비량
def feature_semester(year, semester, semester_list):
    year=str(year)[-2:]
    semester=str(semester)[0:1]
    man=semester_list[semester_list.성별 == '남']['결제금액'].mean()
    woman=semester_list[semester_list.성별 == '여']['결제금액'].mean()
    df=pd.DataFrame({'성별':list(map(round_2,[man,woman]))})
    df.index = ['남자','여자']
    df.plot(kind='bar',stacked=True, figsize=(10,5), color='pink', alpha=0.7)
    plt.xticks(color = 'y')
    plt.yticks(color = 'y')
    plt.legend()
    plt.xlabel(year+'년도 '+semester+'분기',color = 'y', fontsize=15)
    plt.ylabel('평균 결제 금액',color = 'y', fontsize=15)

# %%
feature_semester(20, 1, data_20_1)
feature_semester(20, 2, data_20_2)
feature_semester(20, 3, data_20_3)
feature_semester(20, 4, data_20_4)

# %%
def pay_mean_semester(year, semester_list):
    year=str(year)[-2:]
    semester_list.index=[year+'년도 1분기',year+'년도 2분기',year+'년도 3분기',year+'년도 4분기']
    semester_list.plot(kind='bar',stacked=True, figsize=(10,5), color='pink', alpha=0.7)
    plt.xticks(color = 'y')
    plt.yticks(color = 'y')
    plt.xlabel(year+'년도 분기',color = 'y', fontsize=15)
    plt.ylabel('평균 결제 금액',color = 'y', fontsize=15)

# %%
q=data_20.loc[(data.기준년월 >= 20200101) & (data.기준년월 <=20200331)]['결제금액'].mean()
w=data_20.loc[(data.기준년월 >= 20200401) & (data.기준년월 <=20200631)]['결제금액'].mean()
e=data_20.loc[(data.기준년월 >= 20200701) & (data.기준년월 <=20200931)]['결제금액'].mean()
r=data_20.loc[(data.기준년월 >= 20201001) & (data.기준년월 <=20201231)]['결제금액'].mean()

df_1=pd.DataFrame({'평균결제금액':list(map(round_2,[q,w,e,r]))})

# %%
pay_mean_semester(20, df_1)

# %%
q=data_19.loc[(data.기준년월 >= 20190101) & (data.기준년월 <=20190331)]['결제금액'].mean()
w=data_19.loc[(data.기준년월 >= 20190401) & (data.기준년월 <=20190631)]['결제금액'].mean()
e=data_19.loc[(data.기준년월 >= 20190701) & (data.기준년월 <=20190931)]['결제금액'].mean()
r=data_19.loc[(data.기준년월 >= 20191001) & (data.기준년월 <=20191231)]['결제금액'].mean()

df_2=pd.DataFrame({'평균결제금액':list(map(round_2,[q,w,e,r]))})

# %%
pay_mean_semester(19, df_2)
