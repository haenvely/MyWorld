# %% [markdown]
# ## 탐색적 데이터 분석과정을 생각하면서 나름대로 train_data를 분석해 주세요.

# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('train.csv')
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### 1.  탐색적 데이터 분석: 데이터의 출처와 주제에 대해 이해
# - Kaggle에서 가져온 타이타닉 데이터
# - 타이타닉호의 승객 데이터를 담고 있음

# %% [markdown]
# ### 2. 탐색적 데이터 분석: 데이터의 크기 확인

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train.shape
# Out:
# (891, 12)

# %% [markdown]
# ### 3. 탐색적 데이터 분석: 데이터 구성 요소(feature)의 속성(특징) 확인
# 1. 각 column 이해하기.
#
# raw data에는 다양한 column 이 있는 경우가 많고, 이 중에서 내가 사용할 column 에 대해서는 확실히 이해하고 있어야 한다.

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.matshow(train.corr())

# %% [markdown]
# 2. boolean selection으로 row 선택하기
#
# numpy에서와 동일한 방식으로 해당 조건에 맞는 row만 선택한다.

# %%
# 전체 중 65세 이상 수
len(train[train.Age >= 65])
# Out:
# 11

# %%
#살아남은 사람의 수
len(train[train.Survived == 1])
# Out:
# 342

# %%
# 살아남은 사람 중 여자의 수
len(train[(train.Survived == 1) & (train.Sex == 'female')])
# Out:
# 233

# %%
# 살아남은 사람 중 65세 이상인 사람
len(train[(train.Survived == 1) & (train.Age >=65)])
# Out:
# 1

# %%
len(train[(train.Survived == 1) & (train.Sex == 'female')& (train.Age >=65)])
# Out:
# 0

# %% [markdown]
# ####  3. column 추가하기

# %%
train['Rank'] = train['Fare']*2 + train['Age']
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked      Rank
# 0      0         A/5 21171   7.2500   NaN        S   36.5000
# 1      0          PC 17599  71.2833   C85        C  180.5666
# 2      0  STON/O2. 3101282   7.9250   NaN        S   41.8500
# 3      0            113803  53.1000  C123        S  141.2000
# ...

# %%
train.sort_values(by=['Rank'], axis=0, ascending = False)[0:len(train[train.Survived == 1])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
# 258          259         1       1                    Ward, Miss. Anna
# 438          439         0       1                   Fortune, Mr. Mark
# 341          342         1       1      Fortune, Miss. Alice Elizabeth
# ..           ...       ...     ...                                 ...
# 346          347         1       2           Smith, Miss. Marion Elsie
# 819          820         0       3        Skoog, Master. Karl Thorsten
# 261          262         1       3   Asplund, Master. Edvin Rojj Felix
# 278          279         0       3                  Rice, Master. Eric
# 631          632         0       3         Lundahl, Mr. Johan Svensson
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# ...

# %%
surv_rank = train.sort_values(by=['Rank'], axis=0, ascending = False)[0:len(train[train.Survived == 1])]

# %%
surv_rank['Name']
# Out:
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# 258                      Ward, Miss. Anna
# 438                     Fortune, Mr. Mark
# 341        Fortune, Miss. Alice Elizabeth
#                       ...
# 346             Smith, Miss. Marion Elsie
# 819          Skoog, Master. Karl Thorsten
# 261     Asplund, Master. Edvin Rojj Felix
# 278                    Rice, Master. Eric
# 631           Lundahl, Mr. Johan Svensson
# Name: Name, Length: 342, dtype: object

# %%
# %matplotlib inline
plt.matshow(train.corr())
